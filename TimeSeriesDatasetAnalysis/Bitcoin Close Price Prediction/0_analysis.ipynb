# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r"./bitcoin_price_Training - Training.csv", parse_dates=["Date"])
df.head()
# Out:
#         Date     Open     High      Low    Close         Volume  \
# 0 2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000
# 1 2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000
# 2 2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000
# 3 2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 4 2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000
#
#        Market Cap
# 0  45,535,800,000
# 1  44,890,700,000
# 2  46,246,700,000
# 3  44,144,400,000
# 4  41,816,500,000

# %%
df.describe().T
# Out:
#         count        mean         std    min       25%      50%       75%  \
# Open   1556.0  582.625328  523.137312  68.50  254.2875  438.600  662.4375
# High   1556.0  597.992847  542.992855  74.56  260.3275  447.560  674.5250
# Low    1556.0  567.851446  505.877401  65.53  248.8350  430.570  646.7350
# Close  1556.0  584.239396  525.904442  68.43  254.3200  438.855  663.4025
#
#            max
# Open   2953.22
# High   2999.91
# Low    2840.53
# Close  2958.11

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Volume                object
# Market Cap            object
# dtype: object

# %%
df.set_index(keys=["Date"], inplace=True, drop=True)
df.sort_index(inplace=True)
df.head()
# Out:
#               Open    High     Low   Close Volume     Market Cap
# Date
# 2013-04-28  135.30  135.98  132.10  134.21      -  1,500,520,000
# 2013-04-29  134.44  147.49  134.00  144.54      -  1,491,160,000
# 2013-04-30  144.00  146.93  134.05  139.00      -  1,597,780,000
# 2013-05-01  139.00  139.89  107.72  116.99      -  1,542,820,000
# 2013-05-02  116.38  125.60   92.28  105.21      -  1,292,190,000

# %%
df.Close.plot(ylabel="Daily Bitcoin Price from 2013 to 2020")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Daily Bitcoin Price from 2013 to 2020'>

# %%
df.resample('M').Close.sum().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.resample('Y').Close.sum().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data2 = df.Close
data2.head()
# Out:
# Date
# 2013-04-28    134.21
# 2013-04-29    144.54
# 2013-04-30    139.00
# 2013-05-01    116.99
# 2013-05-02    105.21
# Name: Close, dtype: float64

# %%
data2.index.day_of_week
# Out:
# Int64Index([6, 0, 1, 2, 3, 4, 5, 6, 0, 1,
#             ...
#             5, 6, 0, 1, 2, 3, 4, 5, 6, 0],
#            dtype='int64', name='Date', length=1556)

# %%
weekday = df.groupby([data2.index.day_of_week]).Close.mean()
weekday
# Out:
# Date
# 0    588.738655
# 1    582.402658
# 2    581.731216
# 3    585.565135
# 4    583.876622
# 5    584.545180
# 6    582.802511
# Name: Close, dtype: float64

# %%
weekday.index = ["Sun", "Mon", "Tue", "Wed", "Thru", "Fri", "Sat"]
weekday
# Out:
# Sun     588.738655
# Mon     582.402658
# Tue     581.731216
# Wed     585.565135
# Thru    583.876622
# Fri     584.545180
# Sat     582.802511
# Name: Close, dtype: float64

# %%
weekday.plot()
# Out:
# <AxesSubplot:>

# %%
quarters = df.groupby([data2.index.quarter]).Close
quarters.plot()
# Out:
# Date
# 1    AxesSubplot(0.125,0.2;0.775x0.68)
# 2    AxesSubplot(0.125,0.2;0.775x0.68)
# 3    AxesSubplot(0.125,0.2;0.775x0.68)
# 4    AxesSubplot(0.125,0.2;0.775x0.68)
# Name: Close, dtype: object

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Analysis Trend By Business Day and Weekends

# %%
df["dayofweek"] = df.index.day_of_week
df.head()
# Out:
#               Open    High     Low   Close Volume     Market Cap  dayofweek
# Date
# 2013-04-28  135.30  135.98  132.10  134.21      -  1,500,520,000          6
# 2013-04-29  134.44  147.49  134.00  144.54      -  1,491,160,000          0
# 2013-04-30  144.00  146.93  134.05  139.00      -  1,597,780,000          1
# 2013-05-01  139.00  139.89  107.72  116.99      -  1,542,820,000          2
# 2013-05-02  116.38  125.60   92.28  105.21      -  1,292,190,000          3

# %%
def assign_label(feature):
    return "weekday" if feature < 5 else "weekend"

# %%
df["dayofweek"] = df.dayofweek.map(assign_label)
df.head()
# Out:
#               Open    High     Low   Close Volume     Market Cap dayofweek
# Date
# 2013-04-28  135.30  135.98  132.10  134.21      -  1,500,520,000   weekend
# 2013-04-29  134.44  147.49  134.00  144.54      -  1,491,160,000   weekday
# 2013-04-30  144.00  146.93  134.05  139.00      -  1,597,780,000   weekday
# 2013-05-01  139.00  139.89  107.72  116.99      -  1,542,820,000   weekday
# 2013-05-02  116.38  125.60   92.28  105.21      -  1,292,190,000   weekday

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(14,8))
df[df.dayofweek == "weekend"].plot(ax=ax[0], title="Weekend Trends")
df[df.dayofweek == "weekday"].plot(ax=ax[1], title="Weekdays Trends")
# Out:
# <AxesSubplot:title={'center':'Weekdays Trends'}, xlabel='Date'>

# %% [markdown]
# # Baseline Model (Naive Based)

# %%
df["prediction_naive"] = df.Close.shift(1)
df.head()
# Out:
#               Open    High     Low   Close Volume     Market Cap dayofweek  \
# Date
# 2013-04-28  135.30  135.98  132.10  134.21      -  1,500,520,000   weekend
# 2013-04-29  134.44  147.49  134.00  144.54      -  1,491,160,000   weekday
# 2013-04-30  144.00  146.93  134.05  139.00      -  1,597,780,000   weekday
# 2013-05-01  139.00  139.89  107.72  116.99      -  1,542,820,000   weekday
# 2013-05-02  116.38  125.60   92.28  105.21      -  1,292,190,000   weekday
#
#             prediction_naive
# Date
# 2013-04-28               NaN
# 2013-04-29            134.21
# 2013-04-30            144.54
# 2013-05-01            139.00
# 2013-05-02            116.99

# %%
df[["Close", "prediction_naive"]].plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_true=df["Close"][1:], y_pred=df["prediction_naive"][1:]))
# Out:
# 37.23363264835875

# %% [markdown]
# # Detect Seasonality / Stationality in Dataset
#
# **Seasonality**:
# *Market manipulation* depends upon some factors in time (E.g. Chishtmas, Pujo, Summer, Vaccation etc.). In this example See the **Peaks** repeating year cycle.
#
# **Stationality**:
# If thoughout the dataset timecycle the **Mean and Standard Deviation** almost constant irrespective of time / season / any other factors, this refered as a Stational Dataset.
#
# **Note**:
# Always try to adopt the prediction for the dataset type **Stationary Dataset**. Because in the long run while applying any kind of **TimeSeries Analysis Algorithms (E.g. ARIMA, SARIMA, SARIMAX)** would be result a Better Prediction.
#
# To solve this problem - we generally use **Rolling Mean** Methods (like. RollingHash Function).
#
# An **ARIMA model** is a class of statistical models for analyzing and forecasting time series data. ... ARIMA is an acronym that stands for **AutoRegressive Integrated Moving Average.** It is a generalization of the simpler AutoRegressive Moving Average and adds the notion of integration

# %%
df.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Rolling Windows: Mean, StandardDeviation

# %%
means = df.Close.rolling(window=7).mean()
stds = df.Close.rolling(window=7).std()

# %%
plt.figure(figsize=(15,6))
means.plot(label="mean")
stds.plot(label="std")
df.Close.plot(label="Original", color="b")
plt.legend()

# %% [markdown]
# # Detect: Trend is Seasonal / Stationary?
# For which we are going to perform **Augmented DickeyFuller Testing** on Dataset.
#
# **Augmented Dickey Fuller test (ADF Test)** is a common statistical test used to test whether a given *Time series is stationary or not*. It is one of the most commonly used statistical test when it comes to analyzing the stationary of a series.
#
# **Note:**
# 1) the hypothesis that there is no significant difference between specified populations, any observed difference being due to sampling or experimental error.
#
# 2) In general, a p-value of less than 5% means you can reject the null hypothesis that there is a unit root.
#
# 3) - If **P-value less than 5%**:
#         - Reject Null Hypothesis. **Dataset is Stationary**
#    - If **P-value is greater than 5%**
#         - Failed To Reject NullHypothesis. Meaning Dataset is non-Stationary. In simple way, **dataset is Seasonal.**
#
# 4) P-value is some kind of Probablity Distribution Value. Lies 0 to 1 range.

# %%
from statsmodels.tsa.stattools import adfuller

# %%
df.Close.isna().sum()
# Out:
# 0

# %%
results = adfuller(x=df.Close)
labels = ["ADF Statistics", "P-value", "Lags Used", "No. of Observations"]

for v, l in zip(results,labels):
    print(f"{l} : {v}")
# Out:
# ADF Statistics : 2.5355885873886206
# P-value : 0.9990604352222925
# Lags Used : 24
# No. of Observations : 1531

# %% [markdown]
# # Test for Stationality Using DickeyFuller Test

# %%
def test_for_stationality(feature, df=df):
    means = df[feature].rolling(window=7).mean()
    stds = df[feature].rolling(window=7).std()
    
    plt.figure(figsize=(15,6))
    means.plot(label="mean")
    stds.plot(label="std")
    
    df[feature].plot(label="Original", color="b")
    plt.legend()
    
    results = adfuller(x=df[feature].dropna())
    labels = ["ADF Statistics", "P-value", "Lags Used", "No. of Observations"]

    for v, l in zip(results,labels):
        print(f"{l} : {v}")
    
    return "Data is Stationary" if results[1] <= 0.05 else "Data is Non Stationary"

# %% [markdown]
# # Bitcoins `ClosePrice` AdFuller Test Results

# %%
test_for_stationality('Close')
# Out:
# ADF Statistics : 2.5355885873886206
# P-value : 0.9990604352222925
# Lags Used : 24
# No. of Observations : 1531
# 'Data is Non Stationary'

# %% [markdown]
# # Convertion to Stationary Data
#
# **Log transformation** is a data transformation method in which it replaces each variable x with a log(x). In other words, the log transformation reduces or removes the skewness of our original data. The important caveat here is that the original data has to follow or approximately follow a log-normal distribution.
#
# **When To Use**:
# The log transformation can be used to make highly skewed distributions less skewed.
#
# `Log Transform` is the most popular method to convert the dataset.

# %%
log_transformed_df = np.log(df.Close)
log_transformed_df.plot(color="r")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Why to use Rolling Log_transformed?
#
# To **Smoothening** our Series. Again concept used - **Moving Average(MA)**. (MA) is extensively used in **Stock Market** analysis.

# %%
rolling_mean_ = log_transformed_df - log_transformed_df.shift(7)
rolling_mean_
# Out:
# Date
# 2013-04-28         NaN
# 2013-04-29         NaN
# 2013-04-30         NaN
# 2013-05-01         NaN
# 2013-05-02         NaN
#                 ...
# 2017-07-27   -0.053141
# 2017-07-28    0.051593
# 2017-07-29   -0.030227
# 2017-07-30    0.009760
# 2017-07-31    0.042804
# Name: Close, Length: 1556, dtype: float64

# %%
rolling_mean = log_transformed_df.rolling(window=7).mean()
rolling_mean
# Out:
# Date
# 2013-04-28         NaN
# 2013-04-29         NaN
# 2013-04-30         NaN
# 2013-05-01         NaN
# 2013-05-02         NaN
#                 ...
# 2017-07-27    7.891963
# 2017-07-28    7.899333
# 2017-07-29    7.895015
# 2017-07-30    7.896409
# 2017-07-31    7.902524
# Name: Close, Length: 1556, dtype: float64

# %%
plt.figure(figsize=(14,6))
plt.plot(log_transformed_df, label="Log Transformed", color="b")
plt.plot(rolling_mean, label="Rolling Mean", color="r")
plt.legend()

# %% [markdown]
# # See Lr_diff is a Stationary Data Post AdFuller Test
#
# Steps:
# 1) Perform Log Transformation on Data.
# 2) Find Rolling Mean (Moving Average) by `df[feature].rolling(window=n).mean()`.
# 3) test_for_stationality using custom made function.

# %%
lr_diff = log_transformed_df - rolling_mean
df["lr_diff"] = lr_diff

# %%
test_for_stationality('lr_diff')
# Out:
# ADF Statistics : -7.191325804532465
# P-value : 2.4992600031567963e-10
# Lags Used : 22
# No. of Observations : 1527
# 'Data is Stationary'

# %% [markdown]
# # Using FbProphet Module
#
# Prophet is a procedure for forecasting time series data based on an additive model where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects. It works best with time series that have strong seasonal effects and several seasons of historical data. Prophet is robust to missing data and shifts in the trend, and typically handles outliers well.
#
# Build by [**Facebook**](https://facebook.github.io/prophet/) itself.
#
# **Notes:**
#
# 1. Greatly Handles Irregular Intervals, Holidays in Timeseries Dataset
# 2. Noise / Outlier Handlers in effienct way
#
# **Good Reads**
#
# 1. [ARIMA vs. Prophet: Forecasting](https://towardsdatascience.com/arima-vs-prophet-forecasting-air-passenger-numbers-4e01b2d93608#:~:text=One%20key%20difference%20between%20ARIMA,trend%20in%20the%20time%20series.&text=Prophet%20works%20through%20use%20of,%2C%20weekly%2C%20or%20yearly).)
# 2. [Time Series Forecasting — ARIMA vs Prophet](https://medium.com/analytics-vidhya/time-series-forecasting-arima-vs-prophet-5015928e402a)
# 3. [Time Series With Prophet ML Mastering](https://machinelearningmastery.com/time-series-forecasting-with-prophet-in-python/)

# %%
# !conda install -c conda-forge fbprophet # works
# !pip install fbprophet

# %%
from fbprophet import Prophet
model = Prophet()

# %% [markdown]
# # Forecasting Next 500 Days Bitcoin Closing Price / Trend

# %%
dataset = df[['Close']]
dataset.reset_index(inplace=True)
dataset.columns=['ds', 'y'] # This is mandetory - for Prophet - `ds and y`
dataset.head()
# Out:
#           ds       y
# 0 2013-04-28  134.21
# 1 2013-04-29  144.54
# 2 2013-04-30  139.00
# 3 2013-05-01  116.99
# 4 2013-05-02  105.21

# %%
fitted_model = model.fit(dataset)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -113.741
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       3628.23     0.0335115       1056.34           1           1      119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       3715.66     0.0101665       228.789       0.819       0.819      233
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       3747.26     0.0602088       484.925           1           1      357
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       3786.69    0.00105567       324.984      0.5678      0.5678      474
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       3805.35     0.0115936       432.957           1           1      588
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       3816.34     0.0929513       687.856           1           1      707
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       3845.14     0.0131424       152.046      0.7157      0.7157      819
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      701       3845.22   0.000106633       164.419   4.216e-07       0.001      871  LS failed, Hessian reset
#      799       3850.68     0.0028341       181.037           1           1     1013
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      868       3855.02   0.000488639       794.376   4.627e-07       0.001     1143  LS failed, Hessian reset
#      899       3858.01   0.000465236       224.164       0.133       0.133     1178
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      921       3858.91   0.000326971        162.93   3.002e-06       0.001     1240  LS failed, Hessian reset
#      961       3859.39   5.37053e-05       90.8014   5.915e-07       0.001     1325  LS failed, Hessian reset
#      996       3859.73   0.000143622       228.726   1.059e-06       0.001     1412  LS failed, Hessian reset
#      999       3859.87   0.000452602       71.0815      0.2918           1     1417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099        3860.6   0.000703877       122.391      0.7775      0.7775     1541
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199        3864.9     0.0999513       968.174           1           1     1650
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       3868.15    0.00532789        160.58      0.8867      0.8867     1771
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       3869.58     0.0111331       82.9384           1           1     1898
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1459       3870.45    0.00013493       138.201   1.412e-06       0.001     2020  LS failed, Hessian reset
#     1499       3870.62   7.15309e-07       57.3572      0.7562      0.7562     2074
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1502       3870.62   1.92011e-07       51.9652      0.2968      0.2968     2077
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
future_predictions = fitted_model.make_future_dataframe(periods=500, freq='D', include_history=True)

# %%
forecast = fitted_model.predict(future_predictions)
forecast
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0    2013-04-28   103.554911  -194.548179    62.363985   103.554911
# 1    2013-04-29   101.056502  -188.515590    86.020844   101.056502
# 2    2013-04-30    98.558093  -193.635071    85.072419    98.558093
# 3    2013-05-01    96.059684  -187.107900    83.384802    96.059684
# 4    2013-05-02    93.561275  -187.522630    92.532100    93.561275
# ...         ...          ...          ...          ...          ...
# 2051 2018-12-09  5611.353906  2901.259645  8682.531756  2813.533451
# 2052 2018-12-10  5617.858194  2880.695413  8716.201462  2811.765673
# 2053 2018-12-11  5624.362483  2842.725970  8697.652264  2808.577077
# 2054 2018-12-12  5630.866771  2821.357236  8724.544544  2805.544607
# 2055 2018-12-13  5637.371059  2855.301323  8770.158912  2802.933411
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0      103.554911     -167.305026           -167.305026           -167.305026
# 1      101.056502     -156.854006           -156.854006           -156.854006
# 2       98.558093     -149.506172           -149.506172           -149.506172
# 3       96.059684     -145.638796           -145.638796           -145.638796
# 4       93.561275     -137.189214           -137.189214           -137.189214
# ...           ...             ...                   ...                   ...
# 2051  8685.744385       26.503949             26.503949             26.503949
# 2052  8704.428946       23.841122             23.841122             23.841122
# 2053  8723.113508       17.911193             17.911193             17.911193
# 2054  8741.798069        8.400214              8.400214              8.400214
# 2055  8760.482631        3.427172              3.427172              3.427172
#
#         weekly  weekly_lower  weekly_upper      yearly  yearly_lower  \
# 0    -2.790195     -2.790195     -2.790195 -164.514830   -164.514830
# 1     1.407918      1.407918      1.407918 -158.261924   -158.261924
# 2     2.501927      2.501927      2.501927 -152.008099   -152.008099
# 3     0.089661      0.089661      0.089661 -145.728457   -145.728457
# 4     2.205180      2.205180      2.205180 -139.394394   -139.394394
# ...        ...           ...           ...         ...           ...
# 2051 -2.790195     -2.790195     -2.790195   29.294145     29.294145
# 2052  1.407918      1.407918      1.407918   22.433204     22.433204
# 2053  2.501927      2.501927      2.501927   15.409266     15.409266
# 2054  0.089661      0.089661      0.089661    8.310553      8.310553
# 2055  2.205180      2.205180      2.205180    1.221992      1.221992
#
#       yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0      -164.514830                   0.0                         0.0
# 1      -158.261924                   0.0                         0.0
# 2      -152.008099                   0.0                         0.0
# 3      -145.728457                   0.0                         0.0
# 4      -139.394394                   0.0                         0.0
# ...            ...                   ...                         ...
# 2051     29.294145                   0.0                         0.0
# 2052     22.433204                   0.0                         0.0
# 2053     15.409266                   0.0                         0.0
# 2054      8.310553                   0.0                         0.0
# 2055      1.221992                   0.0                         0.0
#
#       multiplicative_terms_upper         yhat
# 0                            0.0   -63.750115
# 1                            0.0   -55.797504
# 2                            0.0   -50.948079
# 3                            0.0   -49.579112
# 4                            0.0   -43.627939
# ...                          ...          ...
# 2051                         0.0  5637.857856
# 2052                         0.0  5641.699317
# 2053                         0.0  5642.273676
# 2054                         0.0  5639.266984
# 2055                         0.0  5640.798231
#
# [2056 rows x 19 columns]

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(10)
# Out:
#              ds         yhat   yhat_lower   yhat_upper
# 2046 2018-12-04  5639.400013  2909.282205  8738.316910
# 2047 2018-12-05  5638.756403  2914.555799  8633.688375
# 2048 2018-12-06  5642.051522  2909.486864  8607.182856
# 2049 2018-12-07  5639.333263  2883.508697  8666.390804
# 2050 2018-12-08  5638.517990  2893.432699  8698.180261
# 2051 2018-12-09  5637.857856  2901.259645  8682.531756
# 2052 2018-12-10  5641.699317  2880.695413  8716.201462
# 2053 2018-12-11  5642.273676  2842.725970  8697.652264
# 2054 2018-12-12  5639.266984  2821.357236  8724.544544
# 2055 2018-12-13  5640.798231  2855.301323  8770.158912

# %%
model.plot(forecast)

# %%
model.plot_components(fcst=forecast)

# %% [markdown]
# # Calculate Forecast Errors

# %%
from fbprophet.diagnostics import cross_validation

# %%
df_cv = cross_validation(model=model, horizon='365 days', period="180 days", initial="1095 days")
df_cv
# Out:
# INFO:fbprophet:Making 1 forecasts with cutoffs between 2016-07-31 00:00:00 and 2016-07-31 00:00:00
# Initial log joint probability = -26.1633
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       2364.48     0.0543015       384.711           1           1      110
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      198       2443.12   0.000965444       282.565   8.582e-06       0.001      263  LS failed, Hessian reset
#      199       2443.21   0.000886785        227.19           1           1      264
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       2476.98     0.0235916       600.581      0.7834      0.7834      382
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       2506.83    0.00307662       222.155           1           1      503
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      405        2507.7   0.000298689       158.178    1.05e-06       0.001      553  LS failed, Hessian reset
#      463       2510.95   0.000752277       288.729   6.285e-06       0.001      660  LS failed, Hessian reset
#      499       2511.88   0.000281739       82.0058           1           1      708
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      560       2513.85   0.000177362       92.4477   9.527e-07       0.001      814  LS failed, Hessian reset
#      599       2514.17    6.9136e-05       80.3078           1           1      862
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       2515.86   0.000624451       70.5958           1           1      987
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799        2519.5     0.0490629       157.156        1.67       0.167     1103
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      813       2521.03   0.000185933       87.2941   8.486e-07       0.001     1185  LS failed, Hessian reset
#      899       2522.83    0.00472388       102.556      0.2234           1     1289
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      901       2522.84   0.000199295       117.495   2.224e-06       0.001     1339  LS failed, Hessian reset
#      999       2523.09   0.000288537       57.9534           1           1     1463
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1005       2523.14   0.000317962       115.262   3.978e-06       0.001     1524  LS failed, Hessian reset
#     1073       2523.25   8.03257e-05        70.871   9.807e-07       0.001     1658  LS failed, Hessian reset
#     1091       2523.25   1.59906e-06       44.0438   2.632e-08       0.001     1722  LS failed, Hessian reset
#     1099       2523.25    1.9122e-07        68.085      0.4292           1     1734
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1104       2523.25   8.23939e-08        54.664      0.2712      0.6969     1741
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 100%|██████████| 1/1 [00:01<00:00,  1.44s/it]
#             ds         yhat  yhat_lower   yhat_upper        y     cutoff
# 0   2016-08-01   689.363749  610.152306   767.220768   606.27 2016-07-31
# 1   2016-08-02   690.662095  607.428092   769.961114   547.47 2016-07-31
# 2   2016-08-03   690.073114  602.249360   767.369991   566.36 2016-07-31
# 3   2016-08-04   690.951709  611.843990   772.469384   578.29 2016-07-31
# 4   2016-08-05   691.192216  612.677650   779.919661   575.04 2016-07-31
# ..         ...          ...         ...          ...      ...        ...
# 360 2017-07-27  1232.407368  608.500379  1900.732696  2671.78 2016-07-31
# 361 2017-07-28  1233.370785  595.700190  1880.876294  2809.01 2016-07-31
# 362 2017-07-29  1234.922585  584.906619  1879.899121  2726.45 2016-07-31
# 363 2017-07-30  1236.593412  593.552226  1884.528050  2757.18 2016-07-31
# 364 2017-07-31  1241.118818  612.860917  1893.712881  2875.34 2016-07-31
#
# [365 rows x 6 columns]

# %%
from fbprophet.plot import plot_cross_validation_metric

# %%
# metric: Metric name, one of ['mse', 'rmse', 'mae', 'mape', 'coverage'].
plot_cross_validation_metric(df_cv=df_cv, metric="rmse")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/fbprophet/plot.py:526: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])
# /opt/anaconda3/lib/python3.8/site-packages/fbprophet/plot.py:527: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])

# %%
plot_cross_validation_metric(df_cv=df_cv, metric="mse")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/fbprophet/plot.py:526: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])
# /opt/anaconda3/lib/python3.8/site-packages/fbprophet/plot.py:527: FutureWarning: casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').astype(np.int64) / float(dt_conversions[i])
