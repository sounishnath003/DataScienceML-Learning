# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %matplotlib inline

# %%
# !ls
# Out:
# airlines.csv   analysis.ipynb

# %%
df = pd.read_csv("airlines.csv")
df.head()
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0           6            June       2003                            1009
# 1           6            June       2003                             374
# 2           6            June       2003                             296
# 3           6            June       2003                             300
# 4           6            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  \
# ...

# %%
df.describe().T
# Out:
#                                                      count           mean  \
# Time.Month                                          4408.0       6.578947
# Time.Year                                           4408.0    2009.243421
# Statistics.# of Delays.Carrier                      4408.0     574.632486
# Statistics.# of Delays.Late Aircraft                4408.0     789.078947
# Statistics.# of Delays.National Aviation System     4408.0     954.580309
# Statistics.# of Delays.Security                     4408.0       5.575544
# Statistics.# of Delays.Weather                      4408.0      78.216878
# Statistics.Carriers.Total                           4408.0      12.253403
# Statistics.Flights.Cancelled                        4408.0     213.558076
# Statistics.Flights.Delayed                          4408.0    2402.000454
# Statistics.Flights.Diverted                         4408.0      27.880898
# Statistics.Flights.On Time                          4408.0    9254.420826
# ...
